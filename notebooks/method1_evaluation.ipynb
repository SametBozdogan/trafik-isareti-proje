# %% [markdown]
# # Değerlendirme: Yöntem 1
#
# Bu notebook’ta:
# - `eval_method1.py` kodu çalıştırılarak
# - Her model için precision/recall/f1-score
# - Normalized Confusion Matrix görseli
# elde edilecek.

# %%
# Bu kod ile yol sorunu çözülüyor
import os , sys
os.chdir("..")

# %%
# ❷ Test değerlendirme kodunu çalıştır
# %run src/eval_method1.py
# Out:
# *** KNN Classification Report ***
#               precision    recall  f1-score   support
#
#           i2       1.00      0.76      0.86        54
#           i4       0.95      0.87      0.91        91
#           i5       1.00      0.97      0.98       195
#         il60       0.98      1.00      0.99        54
#          p11       0.99      0.91      0.95       181
#          p26       0.96      0.96      0.96        95
#        pl100       0.82      1.00      0.90        73
#         pl30       0.75      0.46      0.57        71
#         pl40       0.92      0.89      0.91       162
#          pl5       1.00      0.94      0.97        65
#         pl50       0.85      0.72      0.78       127
#         pl60       0.80      0.78      0.79        96
#         pl80       0.60      0.89      0.72       108
#           pn       0.95      0.98      0.96       361
#          pne       0.91      0.99      0.95       267
#
#     accuracy                           0.90      2000
# ...
